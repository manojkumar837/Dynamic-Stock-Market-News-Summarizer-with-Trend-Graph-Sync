# %%
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv("NEWS_API")
ALPHA_API = os.getenv("ALPHA_API")
OPENAI = os.getenv("OPENAI")

# %%
# NewsAPI
import requests
import pandas as pd


url = f"https://newsapi.org/v2/everything?q=tesla&apiKey={API_KEY}"

response = requests.get(url)

data = response.json()

articles = data["articles"]

news_list = []

for article in articles:
    news_list.append({
        "title": article["title"],
        "source": article["source"]["name"],
        "published": article["publishedAt"]
    })

df = pd.DataFrame(news_list)

print(df.head())
# Out:
#                                                title       source  \
# 0  Elon Musk admits that millions of Tesla vehicl...    The Verge
# 1  Tesla is recalling its cheaper Cybertruck beca...    The Verge
# 2  Tesla’s revenue rises again as it prepares for...    The Verge
# 3  Tesla hits Musk’s threshold for ‘safe unsuperv...    The Verge
# 4  Tesla Recalls Cybertrucks Over Concerns Their ...  Gizmodo.com
#
#               published
# 0  2026-04-22T22:38:31Z
# 1  2026-05-08T13:48:14Z
# 2  2026-04-22T20:36:17Z
# 3  2026-05-04T14:28:01Z
# 4  2026-05-08T16:45:07Z

# %%
df.to_csv("news_data.csv", index=False)

df.isnull().sum()
# Out:
# title        0
# source       0
# published    0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# title        0
# source       0
# published    0
# dtype: int64

# %%
print(df.shape)
# Out:
# (99, 3)

# %%
#yagoo
import yfinance as yf

data = yf.download("AAPL", period="5d")

print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-05-18  297.839996  300.660004  294.910004  300.239990  34483000
# 2026-05-19  298.970001  300.510010  296.350006  296.970001  42243600
# 2026-05-20  302.250000  302.799988  298.079987  298.179993  38229800
# 2026-05-21  304.989990  305.540009  300.399994  301.059998  42965100
# 2026-05-22  308.820007  311.399994  305.839996  306.119995  43627900

# %%
data.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
print(data.shape)
# Out:
# (5, 5)

# %%
# alpha
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=ALPHA_API, output_format='pandas')

data_a, meta = ts.get_daily(symbol='AAPL')

print(data_a.head())
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2026-05-22  306.120   311.40  305.84    308.82  43670223.0
# 2026-05-21  301.055   305.54  300.40    304.99  42965126.0
# 2026-05-20  298.180   302.80  298.08    302.25  37307876.0
# 2026-05-19  296.970   300.51  296.35    298.97  42243561.0
# 2026-05-18  300.240   300.66  294.91    297.84  34482959.0

# %%
print(data_a.shape)
# Out:
# (100, 5)

# %%
data_a.isnull().sum()
# Out:
# 1. open      0
# 2. high      0
# 3. low       0
# 4. close     0
# 5. volume    0
# dtype: int64
